# %%
import json
from helper.JsonUtil import *

# Replace 'file_path.json' with your actual file path
file_path = '/home/musong/Documents/TCG/TCGPlayBot/parser/json_data/2024-06-11-18-53.json'

# Read the JSON data from the file
with open(file_path, 'r') as file:
    data = json.load(file)

# Display the data
print_pretty_json(data)
# Out:
# {
#  "store": [
#   {
#    "initialDice": 8,
#    "initialHands": 5,
#    "maxDice": 16,
#    "maxHands": 10,
#    "maxRounds": 15,
#    "maxSummons": 4,
#    "maxSupports": 4,
#    "randomSeed": 1404864986
#   },
#   {
#    "random": 1404864986,
#    "id": -500066
#   },
#   {
#    "$$": "characters",
#    "id": 1502
#   },
#   {
#    "health": 10,
#    "energy": 0,
#    "alive": 1,
#    "aura": 0,
#    "maxHealth": 10,
#    "maxEnergy": 3
#   },
#   {
#    "id": -500000,
#    "definition": {
#     "$": 2
#    },
#    "variables": {
#     "$": 3
#    },
#    "entities": [],
#    "damageLog": []
#   },
#   {
#    "$$": "characters",
#    "id": 1503
#   },
#   {
#    "health": 10,
#    "energy": 0,
#    "alive": 1,
#    "aura": 0,
#    "maxHealth": 10,
#    "maxEnergy": 2
#   },
#   {
#    "id": -500001,
#    "definition": {
#     "$": 5
#    },
#    "variables": {
#     "$": 6
#    },
#    "entities": [],
#    "damageLog": []
#   },
#   {
#    "$$": "characters",
#    "id": 1507
# ...

# %%
get_unique_keys(data)
# Out:
# {'log',
#  'log.e',
#  'log.r',
#  'log.s',
#  'log.s.$',
#  'store',
#  'store.$',
#  'store.$$',
#  'store.__type',
#  'store.absorbed',
#  'store.absorbed.$',
#  'store.activeCharacterId',
#  'store.alive',
#  'store.aura',
#  'store.canPlunging',
#  'store.characters',
#  'store.characters.$',
#  'store.combatStatuses',
#  'store.combatStatuses.$',
#  'store.config',
#  'store.config.$',
#  'store.currentSkill',
#  'store.currentTurn',
#  'store.damageLog',
#  'store.damages',
#  'store.damages.$',
#  'store.declaredEnd',
#  'store.definition',
#  'store.definition.$',
#  'store.dice',
#  'store.dice.$',
#  'store.disposeWhenUsageIsZero',
#  'store.disposedSupportCount',
#  'store.disposedSupportCount.$',
#  'store.energy',
#  'store.entities',
#  'store.experience',
#  'store.extensions',
#  'store.extensions.$',
#  'store.hands',
#  'store.hands.$',
#  'store.hasDefeated',
#  'store.hasProgress',
#  'store.health',
#  'store.hintIcon',
#  'store.id',
#  'store.initialDice',
# ...
